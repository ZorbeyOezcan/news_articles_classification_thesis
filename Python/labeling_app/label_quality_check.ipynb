# %% [markdown]
# # Label Quality Check: Embedding-basierte Analyse
# ## UMAP Visualisierung + Outlier Detection pro Klasse
#
# Dieses Notebook analysiert die Qualitaet der hand-gelabelten Daten:
# 1. Artikel mit Sentence-Transformer embedden
# 2. UMAP 2D-Projektion → Klassen-Overlap sichtbar machen
# 3. Outlier Detection (Centroid Distance + LOF) → verdaechtige Samples finden
# 4. Interaktive Inspektion der Outlier

# %%
# === SETUP ===
import subprocess, sys

def _install(pkg):
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", pkg])

for pkg in ["sentence-transformers", "umap-learn", "scikit-learn", "scipy", "matplotlib"]:
    try:
        __import__(pkg.replace("-", "_").split(">")[0])
    except ImportError:
        print(f"Installing {pkg}...")
        _install(pkg)

import os
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.spatial.distance import cdist
from sentence_transformers import SentenceTransformer
from sklearn.neighbors import LocalOutlierFactor
from umap import UMAP

print("Imports OK.")
# Out:
# Installing umap-learn...
# Installing scikit-learn...
# Imports OK.

# %%
# === KONFIGURATION ===
# Hier Parameter anpassen:

# Embedding-Modell (multilingual, gut fuer Deutsch)
MODEL_NAME = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
BATCH_SIZE = 64

# Outlier Detection
CENTROID_PERCENTILE = 95    # Samples ueber diesem Perzentil = Outlier
LOF_NEIGHBORS = 10          # k fuer Local Outlier Factor

# UMAP
UMAP_NEIGHBORS = 15
UMAP_MIN_DIST = 0.1
RANDOM_SEED = 42

# Pfade
BASE_DIR = Path(os.getcwd()).resolve()
DATA_DIR = BASE_DIR / ".." / ".." / "data" / "articles"
LABELED_CSV = DATA_DIR / "cleaned_articles_labeled.csv"
OUTPUT_DIR = BASE_DIR / "label_quality_output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

SKIP_LABELS = {"skipped", "not_clean"}

print(f"Labeled CSV:  {LABELED_CSV}")
print(f"Output:       {OUTPUT_DIR}")
print(f"Modell:       {MODEL_NAME}")
# Out:
# Labeled CSV:  /Users/zorbeyozcan/news_articles_classification_thesis/Python/labeling_app/../../data/articles/cleaned_articles_labeled.csv
# Output:       /Users/zorbeyozcan/news_articles_classification_thesis/Python/labeling_app/label_quality_output
# Modell:       sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2

# %%
# === DATEN LADEN ===
df = pd.read_csv(LABELED_CSV, encoding="utf-8")
df = df[~df["label"].isin(SKIP_LABELS)].reset_index(drop=True)

print(f"Geladen: {len(df)} gelabelte Artikel, {df['label'].nunique()} Klassen\n")
print("Klassenverteilung:")
print(df["label"].value_counts().to_string())
# Out:
# Geladen: 2365 gelabelte Artikel, 13 Klassen
#
# Klassenverteilung:
# label
# Renten                      215
# Gesundheitswesen, Pflege    207
# Kosten/Löhne/Preise         205
# Bundeswehr/Verteidigung     205
# Ukraine/Krieg/Russland      204
# Zuwanderung                 201
# Andere                      200
# Wirtschaftslage             200
# Klima / Energie             200
# AfD/Rechte                  200
# Arbeitslosigkeit            160
# Soziales Gefälle            118
# Politikverdruss              50

# %%
# === EMBEDDINGS BERECHNEN ===
print(f"Lade Modell: {MODEL_NAME}")
model = SentenceTransformer(MODEL_NAME)

# Headline + Text kombinieren (Headline gibt starkes Topic-Signal)
texts = (df["headline"].fillna("") + " \u2014 " + df["text"].fillna("")).tolist()

print(f"Encode {len(texts)} Artikel (batch_size={BATCH_SIZE})...")
embeddings = model.encode(
    texts,
    batch_size=BATCH_SIZE,
    show_progress_bar=True,
    normalize_embeddings=True,
)
print(f"Embedding Shape: {embeddings.shape}")
# Out:
# Lade Modell: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/526 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Encode 2365 Artikel (batch_size=64)...
# Batches:   0%|          | 0/37 [00:00<?, ?it/s]
# Embedding Shape: (2365, 384)

# %%
# === UMAP PROJEKTION ===
print("UMAP laeuft...")
reducer = UMAP(
    n_neighbors=UMAP_NEIGHBORS,
    min_dist=UMAP_MIN_DIST,
    n_components=2,
    metric="cosine",
    random_state=RANDOM_SEED,
)
coords = reducer.fit_transform(embeddings)

df["umap_x"] = coords[:, 0]
df["umap_y"] = coords[:, 1]
print(f"UMAP fertig — Shape: {coords.shape}")
# Out:
# UMAP laeuft...
# /Users/zorbeyozcan/news_articles_classification_thesis/Python/classification_pipeline/.venv/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# UMAP fertig — Shape: (2365, 2)

# %%
# === OUTLIER DETECTION: CENTROID DISTANCE ===
labels = df["label"].values
is_centroid_outlier = np.zeros(len(labels), dtype=bool)
centroid_dists = np.zeros(len(labels))

for lbl in np.unique(labels):
    mask = labels == lbl
    class_emb = embeddings[mask]

    # Zentroid berechnen und normalisieren
    centroid = class_emb.mean(axis=0, keepdims=True)
    centroid /= np.linalg.norm(centroid) + 1e-10

    # Kosinus-Distanz zum Zentroid
    dists = cdist(class_emb, centroid, metric="cosine").flatten()
    centroid_dists[mask] = dists

    threshold = np.percentile(dists, CENTROID_PERCENTILE)
    idx = np.where(mask)[0]
    is_centroid_outlier[idx] = dists > threshold

df["centroid_dist"] = centroid_dists
df["centroid_outlier"] = is_centroid_outlier

print(f"Centroid Outlier ({CENTROID_PERCENTILE}. Perzentil): {is_centroid_outlier.sum()} Artikel geflaggt")
# Out:
# Centroid Outlier (95. Perzentil): 121 Artikel geflaggt

# %%
# === OUTLIER DETECTION: LOCAL OUTLIER FACTOR ===
is_lof_outlier = np.zeros(len(labels), dtype=bool)

for lbl in np.unique(labels):
    mask = labels == lbl
    class_emb = embeddings[mask]

    k = min(LOF_NEIGHBORS, len(class_emb) - 1)
    if k < 2:
        continue

    lof = LocalOutlierFactor(n_neighbors=k, metric="cosine", contamination="auto")
    preds = lof.fit_predict(class_emb)  # -1 = Outlier, 1 = Inlier

    idx = np.where(mask)[0]
    is_lof_outlier[idx] = preds == -1

df["lof_outlier"] = is_lof_outlier

print(f"LOF Outlier (k={LOF_NEIGHBORS}): {is_lof_outlier.sum()} Artikel geflaggt")
print(f"Beide Methoden: {(is_centroid_outlier & is_lof_outlier).sum()} Artikel")
# Out:
# LOF Outlier (k=10): 417 Artikel geflaggt
# Beide Methoden: 59 Artikel

# %%
# === PLOT: UMAP UEBERSICHT ===
unique_labels = np.unique(labels)
cmap = plt.cm.get_cmap("tab20", len(unique_labels))
color_map = {lbl: cmap(i) for i, lbl in enumerate(unique_labels)}

fig, ax = plt.subplots(figsize=(16, 12))
for lbl in unique_labels:
    mask = labels == lbl
    ax.scatter(coords[mask, 0], coords[mask, 1], c=[color_map[lbl]], label=lbl, s=20, alpha=0.6)

ax.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=8, markerscale=2)
ax.set_title("UMAP — Alle gelabelten Artikel nach Klasse", fontsize=14)
ax.set_xlabel("UMAP 1")
ax.set_ylabel("UMAP 2")
plt.tight_layout()
fig.savefig(OUTPUT_DIR / "umap_overview.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# /var/folders/xp/7pdgws4n6_x1j904zf_1h06h0000gn/T/ipykernel_49906/962774831.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab20", len(unique_labels))

# %%
# === PLOT: PER-KLASSE OUTLIER (Centroid + LOF) ===

def plot_class_outliers(coords, labels, outlier_mask, method_name):
    unique_labels = sorted(np.unique(labels))
    n_classes = len(unique_labels)
    cols = 4
    rows = (n_classes + cols - 1) // cols

    fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 4.5 * rows))
    axes = axes.flatten()

    for i, lbl in enumerate(unique_labels):
        ax = axes[i]
        mask = labels == lbl
        class_coords = coords[mask]
        class_outlier = outlier_mask[mask]

        ax.scatter(coords[~mask, 0], coords[~mask, 1], c="lightgray", s=5, alpha=0.15)

        inlier = ~class_outlier
        ax.scatter(class_coords[inlier, 0], class_coords[inlier, 1],
                   c="steelblue", s=18, alpha=0.6, label="Inlier")

        n_out = class_outlier.sum()
        ax.scatter(class_coords[class_outlier, 0], class_coords[class_outlier, 1],
                   c="red", s=40, alpha=0.9, edgecolors="darkred", linewidths=0.5,
                   label=f"Outlier ({n_out})")

        ax.set_title(f"{lbl}", fontsize=10, fontweight="bold")
        ax.legend(fontsize=7, loc="upper right")
        ax.set_xticks([])
        ax.set_yticks([])

    for j in range(i + 1, len(axes)):
        axes[j].set_visible(False)

    fig.suptitle(f"Per-Klasse Outlier ({method_name})", fontsize=14, y=1.01)
    plt.tight_layout()
    fig.savefig(OUTPUT_DIR / f"outliers_per_class_{method_name.lower().replace(' ', '_')}.png",
                dpi=150, bbox_inches="tight")
    plt.show()


print("--- Centroid Distance Outlier ---")
plot_class_outliers(coords, labels, df["centroid_outlier"].values, "Centroid Distance")

print("\n--- LOF Outlier ---")
plot_class_outliers(coords, labels, df["lof_outlier"].values, "LOF")
# Out:
# --- Centroid Distance Outlier ---
# --- LOF Outlier ---

# %%
# === PLOT: DISTANZ-BOXPLOT PRO KLASSE ===
dist_data = []
for lbl in sorted(np.unique(labels)):
    mask = labels == lbl
    for d in centroid_dists[mask]:
        dist_data.append({"label": lbl, "cosine_dist": d})

dist_df = pd.DataFrame(dist_data)

fig, ax = plt.subplots(figsize=(14, 6))
dist_df.boxplot(column="cosine_dist", by="label", ax=ax, rot=45, grid=False)
ax.set_title(f"Kosinus-Distanz zum Klassen-Zentroid (Schwelle: {CENTROID_PERCENTILE}. Perzentil)", fontsize=12)
ax.set_xlabel("")
ax.set_ylabel("Cosine Distance")
fig.suptitle("")
plt.tight_layout()
fig.savefig(OUTPUT_DIR / "centroid_distance_boxplot.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
# === OUTLIER SUMMARY ===
print("=" * 75)
print("OUTLIER SUMMARY")
print("=" * 75)
print(f"{'Klasse':30s}  {'Total':>5s}  {'Centroid':>8s}  {'LOF':>5s}  {'Beide':>5s}")
print("-" * 75)

for lbl in sorted(df["label"].unique()):
    mask = df["label"] == lbl
    n_total = mask.sum()
    n_centroid = df.loc[mask, "centroid_outlier"].sum()
    n_lof = df.loc[mask, "lof_outlier"].sum()
    n_both = (df.loc[mask, "centroid_outlier"] & df.loc[mask, "lof_outlier"]).sum()
    print(f"  {lbl:30s}  {n_total:4d}     {n_centroid:3d}       {n_lof:3d}    {n_both:3d}")

n_flagged = (df["centroid_outlier"] | df["lof_outlier"]).sum()
n_both_total = (df["centroid_outlier"] & df["lof_outlier"]).sum()
print(f"\nTotal geflaggt (mind. 1 Methode): {n_flagged}")
print(f"Geflaggt von BEIDEN Methoden:     {n_both_total}  <-- die verdaechtigsten")
# Out:
# ===========================================================================
# OUTLIER SUMMARY
# ===========================================================================
# Klasse                          Total  Centroid    LOF  Beide
# ---------------------------------------------------------------------------
#   AfD/Rechte                       200      10        14      3
#   Andere                           200      10         0      0
#   Arbeitslosigkeit                 160       8        32      3
#   Bundeswehr/Verteidigung          205      11        33      6
#   Gesundheitswesen, Pflege         207      11        24      7
#   Klima / Energie                  200      10        20      4
#   Kosten/Löhne/Preise              205      11        75      7
#   Politikverdruss                   50       3        26      2
#   Renten                           215      10        61      9
#   Soziales Gefälle                 118       6         9      1
#   Ukraine/Krieg/Russland           204      11        13      7
#   Wirtschaftslage                  200      10       103      8
#   Zuwanderung                      201      10         7      2
#
# Total geflaggt (mind. 1 Methode): 479
# Geflaggt von BEIDEN Methoden:     59  <-- die verdaechtigsten

# %%
# === OUTLIER REPORT SPEICHERN ===
outlier_df = df[df["centroid_outlier"] | df["lof_outlier"]].copy()
outlier_df = outlier_df.sort_values(["label", "centroid_dist"], ascending=[True, False])
outlier_df["text_preview"] = outlier_df["text"].str[:200] + "..."

report_cols = ["id", "label", "headline", "text_preview", "domain",
               "centroid_dist", "centroid_outlier", "lof_outlier"]
report_cols = [c for c in report_cols if c in outlier_df.columns]
report = outlier_df[report_cols]

report_path = OUTPUT_DIR / "outlier_report.csv"
report.to_csv(report_path, index=False, encoding="utf-8")
print(f"Outlier Report gespeichert: {report_path}  ({len(report)} Artikel)")

# Vollstaendiger DataFrame mit allen Scores
full_path = OUTPUT_DIR / "labeled_with_quality_scores.csv"
df.to_csv(full_path, index=False, encoding="utf-8")
print(f"Vollstaendiger DataFrame:   {full_path}")
# Out:
# Outlier Report gespeichert: /Users/zorbeyozcan/news_articles_classification_thesis/Python/labeling_app/label_quality_output/outlier_report.csv  (479 Artikel)
# Vollstaendiger DataFrame:   /Users/zorbeyozcan/news_articles_classification_thesis/Python/labeling_app/label_quality_output/labeled_with_quality_scores.csv

# %%
# === INTERAKTIVE INSPEKTION ===
# Zeigt die verdaechtigsten Outlier (von BEIDEN Methoden geflaggt)

both_outliers = df[df["centroid_outlier"] & df["lof_outlier"]].copy()
both_outliers = both_outliers.sort_values("centroid_dist", ascending=False)

print(f"{len(both_outliers)} Artikel von BEIDEN Methoden geflaggt:\n")

for i, (_, row) in enumerate(both_outliers.iterrows()):
    print(f"{'='*70}")
    print(f"[{i+1}/{len(both_outliers)}]  Label: {row['label']}  |  Centroid-Dist: {row['centroid_dist']:.4f}")
    print(f"ID: {row['id']}  |  Domain: {row.get('domain', 'N/A')}")
    print(f"Headline: {row['headline']}")
    print(f"Text (200 Zeichen): {str(row['text'])[:200]}...")
    print()
# Out:
# 59 Artikel von BEIDEN Methoden geflaggt:
#
# ======================================================================
# [1/59]  Label: Kosten/Löhne/Preise  |  Centroid-Dist: 0.9951
# ID: 62733  |  Domain: bild.de
# Headline: nan
# Text (200 Zeichen): An dieser Stelle findest du den Text-to-Speech Player Um den TTS Player darzustellen, brauchen wir deine Zustimmung. externen Inhalt aktivieren Um eingebettete Inhalte anzuzeigen, ist Ihre jederzeit w...
#
# ======================================================================
# [2/59]  Label: Kosten/Löhne/Preise  |  Centroid-Dist: 0.9893
# ID: 87197  |  Domain: bild.de
# Headline: nan
# Text (200 Zeichen): An dieser Stelle findest du den Text-to-Speech Player Um den TTS Player darzustellen, brauchen wir deine Zustimmung. externen Inhalt aktivieren Um eingebettete Inhalte anzuzeigen, ist Ihre jederzeit w...
#
# ======================================================================
# [3/59]  Label: Wirtschaftslage  |  Centroid-Dist: 0.8962
# ID: 134183  |  Domain: bild.de
# Headline: nan
# Text (200 Zeichen): An dieser Stelle findest du den Text-to-Speech Player Um den TTS Player darzustellen, brauchen wir deine Zustimmung. externen Inhalt aktivieren Um eingebettete Inhalte anzuzeigen, ist Ihre jederzeit w...
#
# ======================================================================
# [4/59]  Label: Kosten/Löhne/Preise  |  Centroid-Dist: 0.8878
# ID: 146931  |  Domain: bild.de
# Headline: nan
# Text (200 Zeichen): An dieser Stelle findest du den Text-to-Speech Player Um den TTS Player darzustellen, brauchen wir deine Zustimmung. externen Inhalt aktivieren Um eingebettete Inhalte anzuzeigen, ist Ihre jederzeit w...
#
# ======================================================================
# [5/59]  Label: Wirtschaftslage  |  Centroid-Dist: 0.8717
# ID: 137041  |  Domain: bild.de
# Headline: nan
# Text (200 Zeichen): An dieser Stelle findest du den Text-to-Speech Player Um den TTS Player darzustellen, brauchen wir deine Zustimmung. externen Inhalt aktivieren Um eingebettete Inhalte anzuzeigen, ist Ihre jederzeit w...
#
# ======================================================================
# [6/59]  Label: Zuwanderung  |  Centroid-Dist: 0.8245
# ID: 241993  |  Domain: spiegel.de
# Headline: Gelöschtes Video: Selena Gomez weint auf Instagram über Trumps Massenabschiebepläne
# Text (200 Zeichen): »I’m sorry«, daneben eine mexikanische Flagge. Selena Gomez, 32, hat am Montag ein Video in ihrer Insta-Story gepostet, in dem sie weinend in die Kamera spricht. »Alle meine Leute werden angegriffen, ...
#
# ======================================================================
# [7/59]  Label: Wirtschaftslage  |  Centroid-Dist: 0.8204
# ID: 166604  |  Domain: schwaebische.de
# Headline: Wichtiger Treffpunkt: Deshalb tummelt sich halb Tuttlingen in Dubai
# Text (200 Zeichen): 23 Grad, Sonne, Meer: Dubai hat im Januar einiges zu bieten. Aber es ist nicht unbedingt das Wetter, das eine ganze Branche in diesen Tagen an den Persischen Golf zieht.
# Vom 27. bis 30. Januar dauert ...
#
# ======================================================================
# [8/59]  Label: Wirtschaftslage  |  Centroid-Dist: 0.7944
# ID: 127998  |  Domain: augsburger-allgemeine.de
# Headline: Homeoffice-Mitarbeiter darf nicht einfach so versetzt werden
# Text (200 Zeichen): Wollen Arbeitgeber Mitarbeiterinnen oder Mitarbeiter an einen anderen Standort versetzen, müssen sie auch deren Interessen berücksichtigen. Sonst kann eine Versetzung unwirksam sein, so ein Urteil. Ar...
#
# ======================================================================
# [9/59]  Label: Renten  |  Centroid-Dist: 0.7733
# ID: 201680  |  Domain: karlsruhe-insider.de
# Headline: Demo findet in Karlsruhe statt &ndash; &quot;Weniger als erwartet&quot;
# Text (200 Zeichen): Eine Demonstrationswelle nach der anderen rollt derzeit über Baden-Württemberg. Nun fand eine weitere Demo in der Karlsruher Innenstadt statt. Zahlreiche Teilnehmer sollten kommen – doch dann waren es...
#
# ======================================================================
# [10/59]  Label: Zuwanderung  |  Centroid-Dist: 0.7583
# ID: 108177  |  Domain: n-tv.de
# Headline: Neuer Höchstand: 2,3 Millionen ausländische Arbeitnehmer im Oktober 2024 in Japan registriert
# Text (200 Zeichen): Die Zahl ausländischer Arbeitnehmer in Japan hat einen neuen Höchststand erreicht. Im Oktober 2024 hatten 2,3 Millionen ausländische Staatsangehörige einen Job in Japan, wie das Arbeitsministerium am ...
#
# ======================================================================
# [11/59]  Label: Bundeswehr/Verteidigung  |  Centroid-Dist: 0.7568
# ID: 153468  |  Domain: bild.de
# Headline: nan
# Text (200 Zeichen): An dieser Stelle findest du den Text-to-Speech Player Um den TTS Player darzustellen, brauchen wir deine Zustimmung. externen Inhalt aktivieren Um eingebettete Inhalte anzuzeigen, ist Ihre jederzeit w...
#
# ======================================================================
# [12/59]  Label: Wirtschaftslage  |  Centroid-Dist: 0.7356
# ID: 184741  |  Domain: ndr.de
# Headline: Urlaub in MV: Landestourismusverband zieht positive Bilanz für 2024
# Text (200 Zeichen): Die Tourismusbranche in Mecklenburg-Vorpommern hat das Jahr 2024 erfolgreich abgeschlossen. Nach ersten Schätzungen des Landestourismusverbands haben zuletzt rund 350.000 Gäste Weihnachten und Neujahr...
#
# ======================================================================
# [13/59]  Label: Klima / Energie  |  Centroid-Dist: 0.7169
# ID: 241592  |  Domain: spiegel.de
# Headline: Großfeuer in Los Angeles: Mindestens 16 Tote, 12.000 Gebäude zerstört oder beschädigt
# Text (200 Zeichen): Im Großraum Los Angeles hat die Feuerwehr eine Ausweitung der Brände im Ortsteil Pacific Palisades verhindern können. Flugzeuge stoppten zunächst das Übergreifen der Flammen in Richtung Osten, indem s...
#
# ======================================================================
# [14/59]  Label: Wirtschaftslage  |  Centroid-Dist: 0.6818
# ID: 141422  |  Domain: fnp.de
# Headline: Verlässliche Finanzausstattung gefordert
# Text (200 Zeichen): Karben (pm). Volkswirte unter sich: CDU-Bundestagskandidat Dr. Thomas Pauls hat kürzlich bei der Tour durch seinen Wahlkreis Karbens Bürgermeister Guido Rahn besucht. Beide haben nicht nur das Parteib...
#
# ======================================================================
# [15/59]  Label: Kosten/Löhne/Preise  |  Centroid-Dist: 0.6755
# ID: 176734  |  Domain: zeit.de
# Headline: Geldpolitik: Fed sezt bei erster Sitzung nach Trumps Start auf Zinspause
# Text (200 Zeichen): Die US-Notenbank Fed tastet den Leitzins in ihrer ersten Sitzung seit dem Wiedereinzug von Donald Trump ins Weiße Haus nicht an. Er liegt damit weiterhin auf hohem Niveau in der Spanne von 4,25 bis 4,...
#
# ======================================================================
# [16/59]  Label: Klima / Energie  |  Centroid-Dist: 0.6714
# ID: 182961  |  Domain: ndr.de
# Headline: Der starke Baum - Mehr als ein stummer Begleiter
# Text (200 Zeichen): Bäume liefern Sauerstoff, binden CO2, speichern Wasser, sind natürliche Klimaanlagen und bieten Lebensraum für Tiere und Insekten. Auch in der Bibel kommen Bäume vor - sie stehen für für Stärke, Schut...
#
# ======================================================================
# [17/59]  Label: Kosten/Löhne/Preise  |  Centroid-Dist: 0.6665
# ID: 182939  |  Domain: ndr.de
# Headline: Nach Tortenangriff auf Lindner: War das Sicherheitskonzept ausreichend?
# Text (200 Zeichen): Nach dem Angriff mit einer Schaumtorte auf FDP-Chef Lindner in Greifswald wird über das Sicherheitskonzept der Veranstaltung diskutiert. Welche Konsequenzen der Angriff für die Tortenwerferin hat, ist...
#
# ======================================================================
# [18/59]  Label: Arbeitslosigkeit  |  Centroid-Dist: 0.6616
# ID: 183349  |  Domain: ndr.de
# Headline: Deutscher Tanzkompanie Neustrelitz droht das Aus
# Text (200 Zeichen): Im kommenden Jahr könnte die "Deutsche Tanzkompanie" ein Jubiläum feiern. Vor 35 Jahren wurde sie in Neustrelitz gegründet. Doch im Moment sieht es nicht nach großem Jubel aus. In wenigen Monaten ende...
#
# ======================================================================
# [19/59]  Label: Klima / Energie  |  Centroid-Dist: 0.6575
# ID: 44111  |  Domain: presseportal.de
# Headline: GEA: Hochtemperatur-Wärmepumpe für Tiense Suiker zur wirtschaftlichen Nutzung von Industrie-Abwärme
# Text (200 Zeichen): GEA hat eine neue Hochtemperatur-Wärmepumpe an den belgischen Zuckerhersteller Tiense Suiker, ein Unternehmen der deutschen Südzucker Group, geliefert und installiert. Die offizielle Eröffnung der Anl...
#
# ======================================================================
# [20/59]  Label: Gesundheitswesen, Pflege  |  Centroid-Dist: 0.6535
# ID: 35956  |  Domain: berliner-zeitung.de
# Headline: „Heldin“ mit Leonie Benesch: Diesen Film sollte jeder sehen
# Text (200 Zeichen): Handlungsort ist eine Station eines Schweizer Krankenhauses, Handlungszeit nur eine Abendschicht. Das Figurenensemble des Films „Heldin“ von Petra Volpe, der in der Sektion Berlinale Special Gala läuf...
#
# ======================================================================
# [21/59]  Label: Kosten/Löhne/Preise  |  Centroid-Dist: 0.6524
# ID: 136178  |  Domain: presseportal.de
# Headline: Wenn die Cloud zur Kostenfalle wird: So gibt Klauke Enterprises Unternehmen die Kontrolle über ihre Daten...
# Text (200 Zeichen): Meschede (ots) Cloud-Dienste entwickeln sich für viele Unternehmen zunehmend zur Kostenfalle, aus der sie sich alleine nicht herauswinden können. Felix Klauke und sein Team der Klauke Enterprises GmbH...
#
# ======================================================================
# [22/59]  Label: Arbeitslosigkeit  |  Centroid-Dist: 0.6521
# ID: 153142  |  Domain: heise.de
# Headline: Salesforce kündigt Mitarbeitern und stellt andere Mitarbeiter ein
# Text (200 Zeichen): 1000 Jobs gehen bei Salesforce Berichten zufolge verloren. Gleichzeitig werden Verkäufer für KI-Produkte eingestellt. close notice This article is also available in English. It was translated with tec...
#
# ======================================================================
# [23/59]  Label: Ukraine/Krieg/Russland  |  Centroid-Dist: 0.6433
# ID: 247548  |  Domain: nordkurier.de
# Headline: Neuer Sabotage-Verdacht in der Ostsee
# Text (200 Zeichen): Neue Kabelschäden und erneute Sabotage-Ermittlungen: Ein weiteres Schiff ist in der Ostsee in den Verdacht geraten, ein unterseeisches Kommunikationskabel mit seinem Anker beschädigt zu haben. Die sch...
#
# ======================================================================
# [24/59]  Label: Wirtschaftslage  |  Centroid-Dist: 0.6337
# ID: 65575  |  Domain: newsflash24.de
# Headline: Das Weltwirtschaftsforum in Davos: Mächtige Elite trifft sich für globale Themen
# Text (200 Zeichen): Geopolitische Herausforderungen und wirtschaftliche Ängste prägen das Spitzentreffen in den Schweizer Alpen. In dieser Woche versammelt sich in Davos, einem Schweizer Wintersportort, die politisch-öko...
#
# ======================================================================
# [25/59]  Label: Soziales Gefälle  |  Centroid-Dist: 0.6319
# ID: 17772  |  Domain: taz.de
# Headline: Die Wahrheit: Spendierhosen bitte
# Text (200 Zeichen): N eulich in der Kölner Heimat durfte ich den Versuch zweier Friedhofsgänger bezeugen, die formalästhetisch recht verwirrende Grabsteinskulptur meines Großvaters zu interpretieren: „Wat soll dat denn b...
#
# ======================================================================
# [26/59]  Label: Wirtschaftslage  |  Centroid-Dist: 0.6193
# ID: 62670  |  Domain: n-tv.de
# Headline: Der Börsen-Tag: Negativer Analystenkommentar drückt Lufthansa-Aktie runter
# Text (200 Zeichen): Ein negativer Analystenkommentar macht der Lufthansa zu schaffen. Die Titel der Fluggesellschaft rutschen um rund vier Prozent ab und sind mit 5,63 Euro so billig wie seit August nicht mehr. Die Exper...
#
# ======================================================================
# [27/59]  Label: Politikverdruss  |  Centroid-Dist: 0.6183
# ID: 53522  |  Domain: noz.de
# Headline: Familienbund schließt sich bundesweiter Initiative an
# Text (200 Zeichen): Wir von hier – das Lokalportal Familienbund schließt sich bundesweiter Initiative an - „Für alle. Mit Herz und Verstand“ Der Familienbund der Katholiken im Bistum Osnabrück hat sich jetzt der Initiati...
#
# ======================================================================
# [28/59]  Label: Gesundheitswesen, Pflege  |  Centroid-Dist: 0.6150
# ID: 223387  |  Domain: volksstimme.de
# Headline: Grippe Erkennen Und Vorbeugen: Grippewelle: Familien liegen flach,  Krankenkasse schaltet Hotline
# Text (200 Zeichen): Die Grippewelle hat begonnen, und es ist wichtig, die Symptome frühzeitig zu erkennen und geeignete Schutzmaßnahmen zu ergreifen. Die Barmer bietet eine kostenlose Hotline unter 0800 84 84 111 an, die...
#
# ======================================================================
# [29/59]  Label: Kosten/Löhne/Preise  |  Centroid-Dist: 0.5965
# ID: 44502  |  Domain: bild.de
# Headline: nan
# Text (200 Zeichen): Für kleines Geld im rollenden Hotel die Gegend erkunden: Für viele ist Camping-Urlaub eine günstige Alternative zu teuren Flugreisen und Hotels mit festen Mauern. Doch der minimalistische Reise-Trend ...
#
# ======================================================================
# [30/59]  Label: Gesundheitswesen, Pflege  |  Centroid-Dist: 0.5961
# ID: 71787  |  Domain: presseportal.de
# Headline: Dr. Christian von Dobschütz zu Besuch in Dr. Becker Kiliani-Klinik
# Text (200 Zeichen): Antrittsbesuch bei Gesundheitsversorger Landrat Dr. Christian von Dobschütz lernt Bad Windsheimer Rehaklinik kennen Am Montag, den 20. Januar, war Dr. Christian von Dobschütz, seit Juli 2024 Landrat v...
#
# ======================================================================
# [31/59]  Label: AfD/Rechte  |  Centroid-Dist: 0.5902
# ID: 130640  |  Domain: fr.de
# Headline: Pflegeversicherung schreibt weiter rote Zahlen – doch die Milliardenlücken bleiben im Wahlkampf unbeachtet
# Text (200 Zeichen): Das Minus der Pflegekassen könnte auf bis zu 1,8 Milliarden Euro ansteigen und auch die Rücklagen für die Gesetzliche Pflegeversicherung sind fast aufgebraucht – Im Wahlkampf findet das Thema wenig Be...
#
# ======================================================================
# [32/59]  Label: Klima / Energie  |  Centroid-Dist: 0.5815
# ID: 40324  |  Domain: augsburger-allgemeine.de
# Headline: La Niña hat begonnen - wie das Phänomen das Wetter verändert
# Text (200 Zeichen): La Niña und El Niño - zwei Wetter-Phänomene, die sich abwechseln. Das eine kühlt das Klima, das andere bewirkt das Gegenteil. Wie lange dauert das La Niña-Ereignis 2025? Bereits im Dezember bemerkte d...
#
# ======================================================================
# [33/59]  Label: AfD/Rechte  |  Centroid-Dist: 0.5773
# ID: 253350  |  Domain: nordkurier.de
# Headline: Gemeinde berät über Festival „Jamel rockt den Förster“
# Text (200 Zeichen): Das bundesweit bekannte Festival „Jamel rockt den Förster“ beschäftigt heute (19.00 Uhr) die Gemeindevertretung Gägelow. In der Sitzung der Gemeinde im Landkreis Nordwestmecklenburg wird über die Fest...
#
# ======================================================================
# [34/59]  Label: Ukraine/Krieg/Russland  |  Centroid-Dist: 0.5770
# ID: 41968  |  Domain: fr.de
# Headline: Trumps nächster Triumph: Gabbard wird trotz Kritik Geheimdienstchefin
# Text (200 Zeichen): Mit knapper Mehrheit bestätigt, von Trump vereidigt: Tulsi Gabbard übernimmt die US-Geheimdienste. Skeptiker warnen vor der riskanten Wahl. Washington DC - Tulsi Gabbard, die ehemalige demokratische K...
#
# ======================================================================
# [35/59]  Label: Arbeitslosigkeit  |  Centroid-Dist: 0.5763
# ID: 221397  |  Domain: rp-online.de
# Headline: Krefeld: Hasan Klauser ist neuer Chef der Agentur für Arbeit
# Text (200 Zeichen): Zum Agenturbezirk Krefeld gehören neben der Agentur für Arbeit an der Philadelphiastraße die Geschäftsstellen Viersen, Kempen und Nettetal mit insgesamt 225 Mitarbeitern. Nach knapp zweieinhalb Jahren...
#
# ======================================================================
# [36/59]  Label: Ukraine/Krieg/Russland  |  Centroid-Dist: 0.5676
# ID: 259836  |  Domain: epochtimes.de
# Headline: 230 alte Tanker: Auch westliche Reeder lieferten Schiffe für russische Schattenflotte
# Text (200 Zeichen): Europäische und US-Reeder haben in den vergangenen Jahren offenbar 230 alte Tankschiffe in die sogenannte russische Schattenflotte verkauft. Zu diesem Ergebnis kommt das internationale Rechercheprojek...
#
# ======================================================================
# [37/59]  Label: Renten  |  Centroid-Dist: 0.5646
# ID: 151901  |  Domain: wz.de
# Headline: Fixkosten, Shopping, Vermögensaufbau: Lehrer aus Moers gibt Finanztipps für junge Menschen
# Text (200 Zeichen): Als Berufsschullehrer für das Fach Wirtschaft am Mercator-Berufskolleg in Moers ist Tobias Nagels in vielen unterschiedlichen Bildungsgängen unterwegs. Eine Sache jedoch gibt es, die seiner Erfahrung ...
#
# ======================================================================
# [38/59]  Label: Gesundheitswesen, Pflege  |  Centroid-Dist: 0.5630
# ID: 184924  |  Domain: ndr.de
# Headline: Unimedizin Greifswald braucht dringend Blutspenden
# Text (200 Zeichen): An der Universitätsmedizin Greifswald (Landkreis Vorpommern-Greifswald) werden Blutkonserven knapp. Deshalb hat sie zu Blutspenden aufgerufen. Den erhöhten Bedarf an Spenden begründet die Unimedizin z...
#
# ======================================================================
# [39/59]  Label: Bundeswehr/Verteidigung  |  Centroid-Dist: 0.5598
# ID: 224592  |  Domain: rp-online.de
# Headline: Düsseldorfer Stadt:Kollektiv zeigt Kriegsspiele im Theater
# Text (200 Zeichen): In „Kriegsspiele“ des Stadt:Kolletkivs werden allerlei Fragen gestellt – wie: Was ist Krieg? Und können Waffen vielleicht Frieden schaffen? Im Unterhaus des Schauspielhauses werden ab dem 22. Februar ...
#
# ======================================================================
# [40/59]  Label: Gesundheitswesen, Pflege  |  Centroid-Dist: 0.5573
# ID: 65368  |  Domain: n-tv.de
# Headline: Wohnen im Alter: Alternative zum Heim: Passt eine Pflege-WG zu mir?
# Text (200 Zeichen): In einer Wohngemeinschaft leben: Das ist nicht nur während des Studiums eine Option, sondern auch im Alter. Fünf Fragen und Antworten rund um die Wohnform Pflege-WG. Wie möchte ich im Alter leben? Ein...
#
# ======================================================================
# [41/59]  Label: Bundeswehr/Verteidigung  |  Centroid-Dist: 0.5543
# ID: 84941  |  Domain: welt.de
# Headline: Rentner sollen für höhere Wehrausgaben Verzicht üben, fordert Ökonom Schularick
# Text (200 Zeichen): Moritz Schularick, Präsident des Kieler Instituts für Weltwirtschaft (IfW), hat eine stärkere Beteiligung von Ruheständlern an höheren Verteidigungsausgaben ins Gespräch gebracht. „Mittel- und langfri...
#
# ======================================================================
# [42/59]  Label: AfD/Rechte  |  Centroid-Dist: 0.5519
# ID: 32534  |  Domain: kreiszeitung.de
# Headline: Bunte Kreuze für die Demokratie
# Text (200 Zeichen): Gelb-pinke Kreuze lehnen oder hängen an Dötlinger Hauswänden. Die Kirchengemeinde des Künstlerdorfs übernimmt die Aktion „Kreuz ohne Haken“ aus Uelzen. Dötlingen wird bunt: Seit einigen Tagen lehnen o...
#
# ======================================================================
# [43/59]  Label: Gesundheitswesen, Pflege  |  Centroid-Dist: 0.5503
# ID: 157936  |  Domain: schwaebische.de
# Headline: Sorge wegen Maul- und Klauenseuche „Angst ist riesig“
# Text (200 Zeichen): Die Bauern in Bayern sind in Sorge wegen der Maul- und Klauenseuche. Außerdem kritisieren sie die Agrarpolitik der Ampel - und haben Forderungen für die Zeit nach der Bundestagswahl.
# Bayerns Bauern si...
#
# ======================================================================
# [44/59]  Label: Gesundheitswesen, Pflege  |  Centroid-Dist: 0.5500
# ID: 201872  |  Domain: tagesspiegel.de
# Headline: Kampf europäischer Länder gegen das Rauchen: Ist ein Zigarettenverbot auch in Deutschland gesetzlich möglich?
# Text (200 Zeichen): Schweden will bis 2025 rauchfrei werden. Großbritannien hat ein Zigaretten-Verkaufsverbot für künftige Generationen beschlossen. Belgien schränkt Einweg-E-Zigaretten ein, in Neuseeland wurde ein ähnli...
#
# ======================================================================
# [45/59]  Label: Renten  |  Centroid-Dist: 0.5421
# ID: 116026  |  Domain: heise.de
# Headline: Frühstart-Rente: Vom ABC-Schützen zum Börsenprofi?
# Text (200 Zeichen): Frühstart-Rente: Vom ABC-Schützen zum Börsenprofi? 23. Januar 2025 Bernd Müller (Bild: LALAKA / Shutterstock.com) CDU-Chef Merz will Kinder ab sechs Jahren zu Börsianern machen. Mit staatlicher Förder...
#
# ======================================================================
# [46/59]  Label: Renten  |  Centroid-Dist: 0.5409
# ID: 205353  |  Domain: bnn.de
# Headline: Zwischen Bretten und Hawaii: Wie zwei Rentnerinnen ihren Traum leben
# Text (200 Zeichen): Die Brettenerin Gabi Mergel und ihre hawaiianische Ehefrau Sharon Nobriga leben ihren Traum. Durch einen bescheidenen Lebensstil und viel Arbeit sind sie früh in Rente gegangen. Sie verbringen jeweils...
#
# ======================================================================
# [47/59]  Label: Politikverdruss  |  Centroid-Dist: 0.5293
# ID: 58752  |  Domain: taz.de
# Headline: Nicht­wäh­le­r*in­nen: Ohne Stimme
# Text (200 Zeichen): Nurefsan Öztürk will Klimaschutz M eine Familie hatte in der Türkei Probleme aus politischen Gründen. Mein Vater hat dort als Polizist mit hohem Rang gearbeitet, auf kommunaler Ebene konnte er einiges...
#
# ======================================================================
# [48/59]  Label: Ukraine/Krieg/Russland  |  Centroid-Dist: 0.5197
# ID: 155683  |  Domain: tagesspiegel.de
# Headline: Auftritte von Scholz, Merz und Habeck: Bei der Münchner Sicherheitskonferenz schlägt die Stunde der Wahlkämpfer
# Text (200 Zeichen): Bundeskanzler Olaf Scholz (SPD), Vizekanzler Robert Habeck (Grüne) und Oppositionsführer Friedrich Merz treten am heutigen Samstag bei der Münchner Sicherheitskonferenz nacheinander auf der Hauptbühne...
#
# ======================================================================
# [49/59]  Label: Renten  |  Centroid-Dist: 0.5155
# ID: 208869  |  Domain: derwesten.de
# Headline: &#8222;Wahlarena&#8220; (ARD): Rentnerin aus Bochum grillt Scholz – &#8222;Komme an Armutsgrenze!&#8220;
# Text (200 Zeichen): Eine Rentnerin ist enttäuscht von der Politik. In der ARD-„Wahlarena“ wird Kanzler Scholz von einer Bochumerin konfrontiert. ARD-„Wahlarena“ am Montagabend – hier haben Bürgerinnen und Bürger die Gele...
#
# ======================================================================
# [50/59]  Label: Ukraine/Krieg/Russland  |  Centroid-Dist: 0.5136
# ID: 245416  |  Domain: nordkurier.de
# Headline: Lawrow lobt AfD und BSW vor Bundestagswahl
# Text (200 Zeichen): Der russische Außenminister Sergej Lawrow hat vor der Bundestagswahl die AfD und das BSW als Verteidiger nationaler deutscher Interessen gelobt. Es gebe in ihren Äußerungen „viel Vernünftiges“, sagte ...
#
# ======================================================================
# [51/59]  Label: Renten  |  Centroid-Dist: 0.5025
# ID: 87825  |  Domain: bild.de
# Headline: nan
# Text (200 Zeichen): Dieser Anti-Aktien-Tweet ging nach hinten los! Gesundheitsminister Karl Lauterbach empört sich auf „X“ über ein Werbeplakat der Online-Plattform „Scalable Capital“, mit der Nutzer u. a. Aktien handeln...
#
# ======================================================================
# [52/59]  Label: Renten  |  Centroid-Dist: 0.5025
# ID: 87825  |  Domain: bild.de
# Headline: nan
# Text (200 Zeichen): Dieser Anti-Aktien-Tweet ging nach hinten los! Gesundheitsminister Karl Lauterbach empört sich auf „X“ über ein Werbeplakat der Online-Plattform „Scalable Capital“, mit der Nutzer u. a. Aktien handeln...
#
# ======================================================================
# [53/59]  Label: Ukraine/Krieg/Russland  |  Centroid-Dist: 0.4941
# ID: 79844  |  Domain: welt.de
# Headline: Belarus: Der hohe Preis für Lukaschenkos Machterhalt
# Text (200 Zeichen): Die zentrale Wahlkommission in Minsk hat in der Nacht auf Montag das Ergebnis der Präsidentschaftswahl bekannt gegeben. Demnach bekam Alexander Lukaschenko 86,82 Prozent der Wählerstimmen. Dass diese ...
#
# ======================================================================
# [54/59]  Label: Renten  |  Centroid-Dist: 0.4938
# ID: 53581  |  Domain: wa.de
# Headline: „Kann es immer noch nicht fassen“: TV-Star verärgert wegen zu geringer Rente
# Text (200 Zeichen): Die Schauspielerin Katerina Jacob ist fassungslos wegen ihrer geringen Rente. Trotz 800.000 Euro Einzahlungen bleibe wenig übrig. Sie ist verärgert. München – Katerina Jacob, bekannt aus den Kultserie...
#
# ======================================================================
# [55/59]  Label: Bundeswehr/Verteidigung  |  Centroid-Dist: 0.4841
# ID: 103694  |  Domain: news.de
# Headline: Olaf Scholz: Bundeskanzler Scholz zur Unverletzlichkeit von Grenzen
# Text (200 Zeichen): Bundeskanzler Olaf Scholz (SPD) hat den designierten US-Präsidenten Donald Trump öffentlich an die Unverletzlichkeit von Grenzen erinnert. Das Statement des Kanzlers dazu im Wortlaut: "Ich habe dieses...
#
# ======================================================================
# [56/59]  Label: Bundeswehr/Verteidigung  |  Centroid-Dist: 0.4841
# ID: 103694  |  Domain: news.de
# Headline: Olaf Scholz: Bundeskanzler Scholz zur Unverletzlichkeit von Grenzen
# Text (200 Zeichen): Bundeskanzler Olaf Scholz (SPD) hat den designierten US-Präsidenten Donald Trump öffentlich an die Unverletzlichkeit von Grenzen erinnert. Das Statement des Kanzlers dazu im Wortlaut: "Ich habe dieses...
#
# ======================================================================
# [57/59]  Label: Renten  |  Centroid-Dist: 0.4825
# ID: 8695  |  Domain: fr.de
# Headline: Plan für die „Rente mit 63“: Die CDU hat eine Überraschung parat
# Text (200 Zeichen): Ein Vorschlag für ihr Wahlprogramm zur Bundestagswahl wurde von den Unionsparteien präsentiert. Die kontroverse „Rente mit 63“ wird darin ebenfalls behandelt. Berlin – Im Wahlkampf um die Bundestagswa...
#
# ======================================================================
# [58/59]  Label: Bundeswehr/Verteidigung  |  Centroid-Dist: 0.4807
# ID: 5597  |  Domain: fr.de
# Headline: Bundestagswahl 2025: Merz will bei Verteidigung Zwei-Prozent-Ziel
# Text (200 Zeichen): Das Rennen um die Bundestagswahl ist eröffnet. Die Parteien bereiten sich auf einen harten Wahlkampf vor. Alle Informationen zu den Neuwahlen im News-Ticker. Update vom 22. Januar, 14.42 Uhr: Kurz vor...
#
# ======================================================================
# [59/59]  Label: Ukraine/Krieg/Russland  |  Centroid-Dist: 0.4700
# ID: 104713  |  Domain: taz.de
# Headline: Meduza-Auswahl 23. – 29. Januar 2025: Immer größere Armut in Russland
# Text (200 Zeichen): Das russisch- und englischsprachige Portal Meduza zählt zu den wichtigsten unabhängigen russischen Medien. Im Januar 2023 wurde Meduza in Russland komplett verboten. Doch Meduza erhebt weiterhin seine...

# %%
# === EINZELNE KLASSE INSPIZIEREN ===
# Klasse hier aendern um Outlier einer bestimmten Klasse zu sehen:

INSPECT_CLASS = "Andere"  # <-- hier aendern

class_outliers = df[
    (df["label"] == INSPECT_CLASS) &
    (df["centroid_outlier"] | df["lof_outlier"])
].sort_values("centroid_dist", ascending=False)

print(f"Outlier in Klasse '{INSPECT_CLASS}': {len(class_outliers)}\n")

for i, (_, row) in enumerate(class_outliers.iterrows()):
    methods = []
    if row["centroid_outlier"]: methods.append("Centroid")
    if row["lof_outlier"]: methods.append("LOF")
    print(f"[{i+1}] Dist={row['centroid_dist']:.4f}  Methode: {'+'.join(methods)}")
    print(f"    Headline: {row['headline']}")
    print(f"    Text: {str(row['text'])[:150]}...")
    print()
# Out:
# Outlier in Klasse 'Andere': 10
#
# [1] Dist=0.8970  Methode: Centroid
#     Headline: Der Tag: Serien-Star Courtney Ford will sich scheiden lassen - Noch-Ehemann soll kein Geld bekommen
#     Text: "Dexter"-Star Courtney Ford und der ehemalige "Superman" Brandon Routh lassen sich nach über 17 Ehejahren scheiden. Wie das US-Promiportal TMZ bericht...
#
# [2] Dist=0.8954  Methode: Centroid
#     Headline: Wirtschafts-Identifikationsnummer (W-IdNr.): Wann bekomme ich eine?
#     Text: Wirtschaftlich tätige Personen erhalten zusätzlich zur Steuer-ID künftig auch eine Wirtschafts-Identifikationsnummer. Das passiert, wenn Sie diese noc...
#
# [3] Dist=0.8498  Methode: Centroid
#     Headline: Besuch in den USA: Netanjahu will mit Trump über Gaza und Iran sprechen
#     Text: Der israelische Regierungschef Benjamin Netanjahu will mit US-Präsident Donald Trump in Washington über die Zukunft des Gazastreifens sprechen. Netanj...
#
# [4] Dist=0.8210  Methode: Centroid
#     Headline: Jetzt neu: Dallmayr Tee Edition Traube Minze
#     Text: Dallmayr Tee Edition Traube Minze Let’s go purple! Dallmayr präsentiert neuen Editionstee. Mit der neuen Tee Edition Traube Minze erweitert Dallmayr s...
#
# [5] Dist=0.8029  Methode: Centroid
#     Headline: Vatikan: Papst Franziskus an beidseitiger Lungenentzündung erkrankt
#     Text: Papst Franziskus leidet an einer beginnenden Lungenentzündung. Wie der Vatikan mitteilte, habe eine Computertomografie des Brustraums gezeigt, dass vo...
#
# [6] Dist=0.8022  Methode: Centroid
#     Headline: JavaScript-Bibliothek React: Neue Umfrage zum Ökosystem zeigt die Trends
#     Text: Laut einer Umfrage haben React-Developer weiterhin mit den gleichen APIs und Hooks zu kämpfen. TanStack Query erhält positive Bewertungen und überholt...
#
# [7] Dist=0.7962  Methode: Centroid
#     Headline: Realschule Weingarten spürt Weihnachten
#     Text: Weihnachtsgottesdienst und gemeinsames Singen
# Die Schulgemeinschaft der Realschule Weingarten stimmte sich mit einem feierlichen Weihnachtsgottesdiens...
#
# [8] Dist=0.7792  Methode: Centroid
#     Headline: Metallsucher finden Münzschatz in Schottland
#     Text: Zwei Metallsucher sind im südlichen Schottland unterwegs, als sie einen ungewöhnlichen Fund machen. Metallsucher haben in Schottland ein glückliches H...
#
# [9] Dist=0.7745  Methode: Centroid
#     Headline: AWO Literaturkreis: Neue Kinderbücher
#     Text: Kinderbücher sind mehr als nur unterhaltsame Geschichten. Sie können Wissen vermitteln, Neugier wecken und junge Leser zu Entdeckern machen. Im Rahmen...
#
# [10] Dist=0.7712  Methode: Centroid
#     Headline: Kassenzettel richtig entsorgen: Niemals in die Papiertonne!
#     Text: Nicht jede Form von Papier gehört auch in die Papiertonne. Das beste Beispiel dafür ist der Kassenzettel. Welche Gefahren bei falscher Entsorgung der ...
